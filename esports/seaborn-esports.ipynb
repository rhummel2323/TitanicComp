# %%
import pandas as pd
import numpy as np
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_theme(style="whitegrid")

#Import file
df_file_path = 'GeneralEsportData.csv'
df = pd.read_csv(df_file_path, encoding='cp1252')
df.head()
# Out:
#                     Game  ReleaseDate     Genre  TotalEarnings  \
# 0         Age of Empires         1997  Strategy      191181.81
# 1      Age of Empires II         1999  Strategy     2296502.80
# 2     Age of Empires III         2005  Strategy       93913.65
# 3      Age of Empires IV         2021  Strategy      151091.75
# 4  Age of Empires Online         2011  Strategy        5356.56
#
#    OnlineEarnings  TotalPlayers  TotalTournaments
# 0       156839.89           261                99
# 1       720999.87          1528              1140
# 2        41800.00           139               120
# 3          217.00           248                79
# 4          775.00            25                17

# %%
df = df.sort_values("TotalEarnings", ascending=False)
df.head()
# Out:
#                                  Game  ReleaseDate  \
# 175                            Dota 2         2013
# 92   Counter-Strike: Global Offensive         2012
# 538                          Fortnite         2017
# 180                 League of Legends         2009
# 542     PLAYERUNKNOWN’S BATTLEGROUNDS         2017
#
#                                Genre  TotalEarnings  OnlineEarnings  \
# 175  Multiplayer Online Battle Arena   2.791530e+08    2.555828e+08
# 92              First-Person Shooter   1.293521e+08    8.350277e+07
# 538                    Battle Royale   1.113393e+08    4.220354e+07
# 180  Multiplayer Online Battle Arena   9.004127e+07    7.959895e+07
# 542                    Battle Royale   4.298136e+07    3.239692e+07
#
#      TotalPlayers  TotalTournaments
# 175          4180              1590
# 92          14708              6081
# 538          4931               750
# 180          8018              2665
# 542          3052               388

# %%
genres = genres.sort_values(by=['TotalEarnings'], ascending=False)
#genres.index

genres_fixed = genres.index

genres_fixed
# Out:
# Index(['Multiplayer Online Battle Arena', 'First-Person Shooter',
#        'Battle Royale', 'Strategy', 'Collectible Card Game', 'Sports',
#        'Fighting Game', 'Racing', 'Role-Playing Game', 'Third-Person Shooter',
#        'Puzzle Game'],
#       dtype='object', name='Genre')

# %%
# Initialize the matplotlib figure (I don't understand this)
f, ax = plt.subplots(figsize=(15, 6))


# Plot the total earnings 
sns.set_color_codes("pastel")
sns.barplot(x="TotalEarnings",
            y="Genre",
            data=df,
            label="Total",
            color="b",
            order=genres_fixed,
            errorbar=None)

# Plot the online earnings
#sns.set_color_codes("muted")
#sns.barplot(x="OnlineEarnings", y="Genre", data=df,
 #           label="Online", color="b", errorbar=None)

# Add a legend and informative axis label
ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(ylabel="",
       xlabel="Earnings (USD)")
sns.despine(left=True, bottom=True)

# %%
#Get a list of all genres
genres = df.groupby(['Genre']).agg(sum)

#genres = genres.index

genres
# Out:
# /tmp/ipykernel_608/1277979464.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   genres = df.groupby(['Genre']).agg(sum)
#                                  ReleaseDate  TotalEarnings  OnlineEarnings  \
# Genre
# Battle Royale                          26233   2.020335e+08    1.032892e+08
# Collectible Card Game                  34261   4.161249e+07    2.899262e+07
# Fighting Game                         347869   2.380341e+07    2.120143e+07
# First-Person Shooter                  231244   2.969696e+08    1.981468e+08
# Multiplayer Online Battle Arena        50347   4.459746e+08    4.001939e+08
# Puzzle Game                            34138   7.277689e+04    3.870185e+04
# Racing                                110644   1.198667e+07    5.911487e+06
# Role-Playing Game                      12061   8.411453e+06    5.927244e+06
# Sports                                148866   3.810440e+07    2.122819e+07
# Strategy                              106603   7.757820e+07    5.639600e+07
# Third-Person Shooter                   20151   5.512086e+06    4.296751e+06
#
#                                  TotalPlayers  TotalTournaments
# Genre
# Battle Royale                           12450              1686
# Collectible Card Game                    4425              1618
# Fighting Game                           14108             10069
# First-Person Shooter                    44506             13348
# Multiplayer Online Battle Arena         17291              5539
# Puzzle Game                               216                89
# Racing                                   3843              1330
# Role-Playing Game                         820               255
# Sports                                   4689              3115
# Strategy                                 9295             10940
# Third-Person Shooter                      474                98

# %%
# Initialize the matplotlib figure (I don't understand this)
f, ax = plt.subplots(figsize=(15, 6))


# Plot the total earnings 
sns.set_color_codes("pastel")
sns.barplot(x="TotalEarnings", y=genres.index, data=genres,
            label="Total", color="b", errorbar=None)

# Plot the online earnins
sns.set_color_codes("muted")
sns.barplot(x="OnlineEarnings", y=genres.index, data=genres,
            label="Online", color="b", errorbar=None)

# Add a legend and informative axis label
ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(ylabel="",
       xlabel="Earnings (USD)")
sns.despine(left=True, bottom=True)

# %%
test = 'Strategy'
genre_df = df.loc[df['Genre'] == test]
# Initialize the matplotlib figure (I don't understand this)
f, ax = plt.subplots(figsize=(15, 6))


# Plot the total earnings 
sns.set_color_codes("pastel")
sns.barplot(x="TotalEarnings", y="Game", data=genre_df,
            label="Total", color="b", errorbar=None)

#Plot the online earnins
sns.set_color_codes("muted")
sns.barplot(x="OnlineEarnings", y="Game", data=genre_df,
    label="Online", color="b", errorbar=None)

# Add a legend and informative axis label
ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(ylabel="",
        xlabel="Earnings (USD)")
sns.despine(left=True, bottom=True)
